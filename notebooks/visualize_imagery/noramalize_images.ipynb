# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from src.models.data import *

# %%
test_path = "../../data/test"

# %%
data_gen_args = dict(
                    data_format="channels_last",
                    horizontal_flip=True,
#                     samplewise_std_normalization=True,
#                     rescale=1/255,
#                     samplewise_center=True
 )

# %%
image_datagen= ImageDataGenerator(data_gen_args)
# test_datgen = image_datagen.flow_from_directory(test_path, 
#                                                 classes=["sat"], 
#                                                 batch_size=1, 
#                                                 class_mode=None,
#                                                 color_mode="rgb",
#                                                 target_size=(512,512),
#                                                 seed=1
#                                                )

test_datgen = trainGenerator(1,'../../data/test','sat','map',
                        data_gen_args,save_to_dir = None,image_color_mode="rgba", 
                             target_size=(512,512))

# %%
def normalize(sat):
    sat = sat/255
#     sat[:, :, :, 2] = 0
#     sat[:, :, :, 1] = 0
#     print(sat[1:1])
    sat = (sat - np.mean(sat))/ np.std(sat)
    return sat

# %%
def show(n, sat, map):
    figH1 = plt.figure(n, figsize=(25, 6))
    plt.subplot(1, 3, 1)
    plt.imshow(sat[0])
    
    print(map.shape)
    plt.subplot(1, 3, 2)
    plt.imshow(map[0].reshape((512,512)), cmap='gray')

#     plt.subplot(1, 3, 3)
#     plt.imshow(p, cmap='gray')

    plt.colorbar()
    figH1.show()

# %%
n = 0
for sat,map in test_datgen:
    show(n,sat, map)
    n +=1
    if n >= 10:
       break
# Out:
# Found 380 images belonging to 1 classes.
# Found 380 images belonging to 1 classes.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /Users/kprakash/.pyenv/versions/3.6.5/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 512, 512, 1)
# (1, 512, 512, 1)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
