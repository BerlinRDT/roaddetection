# %% [markdown]
# # Satellite image list management
# This notebook
# * reads a file which lists all satellite images to be used for training image generation
# * places the contents into a dataframe and displays it
# * does a few sanity checks
# * is the basis for other notebooks that actually do something with the data (e.g. searching for them)

# %%
import pandas as pd

# %%
# name of the file containing the list (as json; one entry per line)
# fn = "/media/hh/hd_internal/_data_DS/DSR/satelliteImages/list_satellite_images_training.txt"
fn = "../../list_satellite_images_training.json"
img_list = pd.read_json(fn)
img_list
# Out:
#    AOIName                           analyticImgName  \
# 0    Harz3    20180419_074323_0c43_3B_AnalyticMS.tif
# 1    Harz3    20180419_074324_0c43_3B_AnalyticMS.tif
# 2    Harz3  20180419_074324_1_0c43_3B_AnalyticMS.tif
# 3    Harz3    20180419_074325_0c43_3B_AnalyticMS.tif
# 4    Harz3    20180419_074326_0c43_3B_AnalyticMS.tif
# 5    Harz1    20180504_094435_0e19_3B_AnalyticMS.tif
# 6    Harz1    20180724_094554_0e19_3B_AnalyticMS.tif
# 7     3093    20180427_020503_103c_3B_AnalyticMS.tif
# 8     3093    20180427_020504_103c_3B_AnalyticMS.tif
# 9     3093    20180606_020625_0f1b_3B_AnalyticMS.tif
# 10    3093    20180427_020503_103c_3B_AnalyticMS.tif
# 11    3093    20180427_020504_103c_3B_AnalyticMS.tif
# 12    3093    20180606_020625_0f1b_3B_AnalyticMS.tif
# 13    3093    20170815_005028_0c0b_3B_AnalyticMS.tif
# 14    3093    20170815_005030_0c0b_3B_AnalyticMS.tif
# 15    3093    20170920_015736_0f28_3B_AnalyticMS.tif
# 16    3093    20171013_232848_0c46_3B_AnalyticMS.tif
# 17    3093    20180310_020202_1040_3B_AnalyticMS.tif
# 18    3093    20180427_020346_103a_3B_AnalyticMS.tif
# 19    3093    20180427_020347_103a_3B_AnalyticMS.tif
# 20    3093    20180427_020501_103c_3B_AnalyticMS.tif
# 21    3093    20180427_020502_103c_3B_AnalyticMS.tif
#
#                                               comment     directory  doUse  \
# 0                        curated OpenStreetMap labels         Harz/      1
# 1                        curated OpenStreetMap labels         Harz/      1
# 2                        curated OpenStreetMap labels         Harz/      1
# 3                        curated OpenStreetMap labels         Harz/      1
# 4                        curated OpenStreetMap labels         Harz/      1
# 5                        curated OpenStreetMap labels         Harz/      1
# 6                        curated OpenStreetMap labels         Harz/      1
# 7                                   RDT manual labels  Borneo/3093/      0
# 8                                   RDT manual labels  Borneo/3093/      0
# 9                                   RDT manual labels  Borneo/3093/      0
# 10  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 11  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 12  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 13  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 14  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 15  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 16  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 17  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 18  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 19  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 20  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
# 21  curated OpenStreetMap & curated Laurance group...  Borneo/3093/      1
#
#                                        labelFileNames
# 0                      RoadLabels_RDT_Harz3_a.geojson
# 1                      RoadLabels_RDT_Harz3_a.geojson
# 2                      RoadLabels_RDT_Harz3_a.geojson
# 3                      RoadLabels_RDT_Harz3_a.geojson
# 4                      RoadLabels_RDT_Harz3_a.geojson
# 5                      RoadLabels_RDT_Harz1_a.geojson
# 6                      RoadLabels_RDT_Harz1_a.geojson
# 7                           RoadLabels_RDT_3093_a.kml
# 8                           RoadLabels_RDT_3093_a.kml
# 9                           RoadLabels_RDT_3093_a.kml
# 10  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 11  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 12  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 13  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 14  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 15  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 16  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 17  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 18  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 19  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 20  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...
# 21  RoadLabels_RDT_3093_OSM.kml, RoadLabels_Lauran...

# %% [markdown]
# ## Some sanity checks of list

# %%
# alert to duplicate files which have identical label file names - these are likely indadvertent duplicates
assert(not any(img_list.duplicated(["analyticImgName","labelFileNames"]))), "Duplicate entries in list"

# display duplicate files (which is fine if they have different underlying labelFileNames)
duplicate_img_ix = img_list.duplicated(["analyticImgName"])
if any(duplicate_img_ix):
    print("The following image files are listed more than once, but with different label filenames:")
    print((img_list.loc[duplicate_img_ix,"analyticImgName"]))
# Out:
# The following image files are listed more than once, but with different label filenames:
# 10    20180427_020503_103c_3B_AnalyticMS.tif
# 11    20180427_020504_103c_3B_AnalyticMS.tif
# 12    20180606_020625_0f1b_3B_AnalyticMS.tif
# Name: analyticImgName, dtype: object

# %% [markdown]
# ## Check that all files listed are in directories and vice versa

# %%
# to come

# %%
# img_list.loc[img_list.directory.str.contains('borneo', case=False)]
